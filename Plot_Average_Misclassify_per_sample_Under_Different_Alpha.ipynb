# %%
import matplotlib.pyplot as plt

# %%
x = [0.0, 0.01, 0.1, 0.3, 0.5, 1.0]
y = [6.67382, 5.63024, 3.24082, 1.19512, 1.68622, 4.30236]

# %%
plt.plot(x,y, marker='o')
plt.xlabel(r'Gaussian Noise Intensity $\alpha$ ')
plt.ylabel('Average Misclassify Amount per Sample')
plt.title(r'Average Misclassify Amount per Sample under hardware noise $\sigma$ = 0.2 (30 runs)')
# r' Average Misclassify Samples with Different $\alpha$ under same $\sigma$ = 0.2'
# Out:
# Text(0.5, 1.0, 'Average Misclassify Amount per Sample under hardware noise $\\sigma$ = 0.2 (30 runs)')
